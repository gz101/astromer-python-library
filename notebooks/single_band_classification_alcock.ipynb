# %%
import sys
import os

astromer_path = ".."
sys.path.append(astromer_path)

# %%
import pandas as pd

from ASTROMER.core.data import pretraining_records
from ASTROMER.models import SingleBandEncoder

# %%
train_data = pretraining_records(
    "/Users/gchiong/Downloads/alcock/fold_0/alcock_500/train",
    batch_size=256,
    shuffle=True,
    max_obs=200,
    msk_frac=0.5,
    rnd_frac=0.2,
    same_frac=0.2,
)

val_data = pretraining_records(
    "/Users/gchiong/Downloads/alcock/fold_0/alcock_500/val",
    batch_size=256,
    shuffle=True,
    max_obs=200,
    msk_frac=0.5,
    rnd_frac=0.2,
    same_frac=0.2,
)

test_data = pretraining_records(
    "/Users/gchiong/Downloads/alcock/fold_0/alcock_500/test",
    batch_size=256,
    shuffle=True,
    max_obs=200,
    msk_frac=0.5,
    rnd_frac=0.2,
    same_frac=0.2,
)

label_dict = pd.read_csv("/Users/gchiong/Downloads/alcock/fold_0/alcock_500/objects.csv")["label"].to_dict()

# %%
train_data.take(2)
# Out:
# <_TakeDataset element_spec={'output': TensorSpec(shape=(None, None, 1), dtype=tf.float32, name=None), 'input': TensorSpec(shape=(None, None, None), dtype=tf.float32, name=None), 'times': TensorSpec(shape=(None, None, 1), dtype=tf.float32, name=None), 'mask_out': TensorSpec(shape=(None, None, 1), dtype=tf.float32, name=None), 'mask_in': TensorSpec(shape=(None, None, 1), dtype=tf.float32, name=None), 'length': TensorSpec(shape=(None,), dtype=tf.int32, name=None), 'label': TensorSpec(shape=(None,), dtype=tf.int32, name=None), 'id': TensorSpec(shape=(None,), dtype=tf.string, name=None)}>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization


def get_mlp_backprop(num_classes, maxlen=200):
    ''' FC + ATT'''
    inputs = {
        'input': tf.keras.Input(shape=(maxlen, 1), name='input'),
        'times': tf.keras.Input(shape=(maxlen, 1), name='times'),
        'mask_in': tf.keras.Input(shape=(maxlen, 1), name='mask'),
        'length': tf.keras.Input(shape=(maxlen, 1), name='length'),
    }

    model = SingleBandEncoder()
    model.from_pretraining("macho")

    model.model.trainable = False
    encoder = model.model.get_layer("encoder")

    m = tf.cast(1.-inputs['mask_in'][...,0], tf.bool)
    x = encoder(inputs)
    x = tf.ragged.boolean_mask(x, m)
    x = tf.reduce_mean(x, 1)

    x = Dense(1024, activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Dense(num_classes, activation='softmax')(x)
    return tf.keras.Model(inputs=inputs, outputs=x, name="MLP_ATT")

# %%
classes = len(label_dict)

# %%
model_MLP = get_mlp_backprop(classes)
model_MLP.summary()
# Out:
# [INFO] Weights already downloaded
# Model: "MLP_ATT"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  mask (InputLayer)           [(None, 200, 1)]             0         []
#
#  tf.__operators__.getitem (  (None, 200)                  0         ['mask[0][0]']
#  SlicingOpLambda)
#
#  tf.math.subtract (TFOpLamb  (None, 200)                  0         ['tf.__operators__.getitem[0][
#  da)                                                                0]']
#
#  input (InputLayer)          [(None, 200, 1)]             0         []
#
#  length (InputLayer)         [(None, 200, 1)]             0         []
#
#  times (InputLayer)          [(None, 200, 1)]             0         []
#
#  tf.cast (TFOpLambda)        (None, 200)                  0         ['tf.math.subtract[0][0]']
#
#  encoder (Encoder)           (None, None, 200)            529312    ['input[0][0]',
#                                                                      'length[0][0]',
#                                                                      'mask[0][0]',
#                                                                      'times[0][0]']
#
#  tf.convert_to_tensor_1 (TF  (None, 200)                  0         ['tf.cast[0][0]']
#  OpLambda)
#
#  tf.convert_to_tensor (TFOp  (None, None, 200)            0         ['encoder[1][0]']
#  Lambda)
#
#  tf.math.count_nonzero (TFO  (None,)                      0         ['tf.convert_to_tensor_1[0][0]
#  pLambda)                                                           ']
#
#  tf.compat.v1.boolean_mask   (None, 200)                  0         ['tf.convert_to_tensor[0][0]',
#  (SlicingOpLambda)                                                   'tf.convert_to_tensor_1[0][0]
#                                                                     ']
#
#  tf.reshape (TFOpLambda)     (None,)                      0         ['tf.math.count_nonzero[0][0]'
#                                                                     ]
#
#  tf.RaggedTensor.from_row_l  (None, None, 200)            0         ['tf.compat.v1.boolean_mask[0]
#  engths (ClassMethod)                                               [0]',
#                                                                      'tf.reshape[0][0]']
#
#  tf.math.reduce_mean (TFOpL  (None, 200)                  0         ['tf.RaggedTensor.from_row_len
#  ambda)                                                             gths[0][0]']
#
#  dense_10 (Dense)            (None, 1024)                 204800    ['tf.math.reduce_mean[0][0]']
#
#  batch_normalization (Batch  (None, 1024)                 4096      ['dense_10[0][0]']
#  Normalization)
#
#  dense_11 (Dense)            (None, 512)                  524288    ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 512)                  2048      ['dense_11[0][0]']
#  chNormalization)
#
#  dense_12 (Dense)            (None, 256)                  131072    ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 256)                  1024      ['dense_12[0][0]']
#  chNormalization)
#
#  dense_13 (Dense)            (None, 6)                    1542      ['batch_normalization_2[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 1398182 (5.33 MB)
# Trainable params: 865286 (3.30 MB)
# Non-trainable params: 532896 (2.03 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy


estop = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=50,
    mode='auto',
    restore_best_weights=True,
)

optimizer = Adam(learning_rate=5e-4)

model_MLP.compile(
    optimizer=optimizer,
    loss=SparseCategoricalCrossentropy(),
    metrics='accuracy'
)

# %%
def extract_inputs_and_targets(data):
    inputs = {
        'input': data['input'],
        'times': data['times'],
        'mask_in': data['mask_in'],
        'length': data['length'],
    }
    targets = data['label']
    return inputs, targets

# %%
train_data_prepared = train_data.map(extract_inputs_and_targets)
val_data_prepared = val_data.map(extract_inputs_and_targets)

# %%
hist = model_MLP.fit(
    train_data_prepared, 
    epochs=25,
    validation_data=val_data_prepared,
    callbacks=[estop],
    verbose=2,
)
# Out:
# Epoch 1/25
# 38/38 - 17s - loss: 1.9132 - accuracy: 0.2291 - val_loss: 1.8201 - val_accuracy: 0.1732 - 17s/epoch - 436ms/step
# Epoch 2/25
# 38/38 - 15s - loss: 1.6905 - accuracy: 0.2701 - val_loss: 1.7964 - val_accuracy: 0.1943 - 15s/epoch - 402ms/step
# Epoch 3/25
# 38/38 - 16s - loss: 1.6484 - accuracy: 0.2825 - val_loss: 1.7625 - val_accuracy: 0.2315 - 16s/epoch - 409ms/step
# Epoch 4/25
# 38/38 - 15s - loss: 1.6260 - accuracy: 0.2939 - val_loss: 1.7473 - val_accuracy: 0.2256 - 15s/epoch - 407ms/step
# Epoch 5/25
# 38/38 - 16s - loss: 1.6043 - accuracy: 0.3022 - val_loss: 1.7470 - val_accuracy: 0.2315 - 16s/epoch - 410ms/step
# Epoch 6/25
# 38/38 - 16s - loss: 1.5925 - accuracy: 0.3065 - val_loss: 1.7289 - val_accuracy: 0.2214 - 16s/epoch - 411ms/step
# Epoch 7/25
# 38/38 - 16s - loss: 1.5803 - accuracy: 0.3191 - val_loss: 1.7426 - val_accuracy: 0.2239 - 16s/epoch - 412ms/step
# Epoch 8/25
# 38/38 - 16s - loss: 1.5724 - accuracy: 0.3176 - val_loss: 1.7296 - val_accuracy: 0.2125 - 16s/epoch - 414ms/step
# Epoch 9/25
# 38/38 - 25s - loss: 1.5567 - accuracy: 0.3243 - val_loss: 1.7202 - val_accuracy: 0.2307 - 25s/epoch - 655ms/step
# Epoch 10/25
# 38/38 - 16s - loss: 1.5507 - accuracy: 0.3277 - val_loss: 1.7346 - val_accuracy: 0.2493 - 16s/epoch - 421ms/step
# Epoch 11/25
# 38/38 - 16s - loss: 1.5423 - accuracy: 0.3314 - val_loss: 1.7225 - val_accuracy: 0.2564 - 16s/epoch - 421ms/step
# Epoch 12/25
# 38/38 - 16s - loss: 1.5353 - accuracy: 0.3356 - val_loss: 1.7940 - val_accuracy: 0.2248 - 16s/epoch - 416ms/step
# Epoch 13/25
# 38/38 - 16s - loss: 1.5229 - accuracy: 0.3474 - val_loss: 1.7843 - val_accuracy: 0.2379 - 16s/epoch - 416ms/step
# Epoch 14/25
# 38/38 - 16s - loss: 1.5184 - accuracy: 0.3467 - val_loss: 1.7607 - val_accuracy: 0.2239 - 16s/epoch - 418ms/step
# Epoch 15/25
# 38/38 - 16s - loss: 1.5181 - accuracy: 0.3460 - val_loss: 1.8028 - val_accuracy: 0.2269 - 16s/epoch - 428ms/step
# Epoch 16/25
# 38/38 - 16s - loss: 1.5106 - accuracy: 0.3486 - val_loss: 1.7707 - val_accuracy: 0.2446 - 16s/epoch - 423ms/step
# Epoch 17/25
# 38/38 - 16s - loss: 1.5007 - accuracy: 0.3554 - val_loss: 1.7924 - val_accuracy: 0.2510 - 16s/epoch - 428ms/step
# Epoch 18/25
# 38/38 - 16s - loss: 1.4920 - accuracy: 0.3603 - val_loss: 1.8306 - val_accuracy: 0.2442 - 16s/epoch - 427ms/step
# Epoch 19/25
# 38/38 - 16s - loss: 1.4850 - accuracy: 0.3557 - val_loss: 1.7667 - val_accuracy: 0.2463 - 16s/epoch - 430ms/step
# Epoch 20/25
# 38/38 - 16s - loss: 1.4824 - accuracy: 0.3623 - val_loss: 1.8794 - val_accuracy: 0.2429 - 16s/epoch - 432ms/step
# Epoch 21/25
# 38/38 - 17s - loss: 1.4803 - accuracy: 0.3656 - val_loss: 1.8457 - val_accuracy: 0.2463 - 17s/epoch - 434ms/step
# Epoch 22/25
# 38/38 - 17s - loss: 1.4704 - accuracy: 0.3719 - val_loss: 2.0966 - val_accuracy: 0.1939 - 17s/epoch - 436ms/step
# Epoch 23/25
# 38/38 - 17s - loss: 1.4728 - accuracy: 0.3643 - val_loss: 1.8791 - val_accuracy: 0.2408 - 17s/epoch - 437ms/step
# Epoch 24/25
# 38/38 - 17s - loss: 1.4583 - accuracy: 0.3732 - val_loss: 1.8319 - val_accuracy: 0.2446 - 17s/epoch - 435ms/step
# Epoch 25/25
# 38/38 - 17s - loss: 1.4553 - accuracy: 0.3827 - val_loss: 1.9025 - val_accuracy: 0.2433 - 17s/epoch - 439ms/step

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))
epochs = hist.epoch
ax = fig.add_subplot(1,2,1)
ax.plot(epochs,hist.history['loss'],label = 'loss')
ax.plot(epochs,hist.history['val_loss'],label = 'validation loss')
ax.set_title("Loss vs Epochs")
ax.legend()
ax = fig.add_subplot(1,2,2)
ax.plot(epochs,hist.history['accuracy'],label = 'accuracy')
ax.plot(epochs,hist.history['val_accuracy'],label = 'validation accuracy')
ax.set_title("Accuracy vs Epochs")
ax.legend();
